# %% [markdown]
# # DEODE training
# ## Query from SQLite files and making a plot(?)

# %%
# Personal info
username = 'nknt'
path_to_exercises = f'/home/{username}/deode/DE330_Training_2024/Exercises/'
path_to_domain = f'/perm/{username}/git/github/natalieth/deode/develop/deode/data/config_files/include/domains/DEMO_60x80_2500m.toml'

# %%
import sqlite3

# %%
db_t2m = f"/ec/res4/scratch/nknt/deode/CY48t3_ALARO/archive/sqlite/FCTABLE/CY48t3_ALARO/2023/09/FCTABLE_T2m_202309_00.sqlite"
conn = sqlite3.connect(db_t2m)
print(conn)
cur = conn.cursor()
cur.execute("SELECT * FROM FC;")
print(cur.fetchall())
# Out:
# ...
# [(1694822400.0, 0.0, 6209, 2, 52.4636, 4.5175, 1694822400, 'T2m', 'K', 291.7012024248851, 0.0, 0.0), (1694822400.0, 0.0, 6210, 2, 52.1703, 4.4294, 1694822400, 'T2m', 'K', 289.78967965012646, 1.38, 0.0), (1694822400.0, 0.0, 6225, 2, 52.4622, 4.555, 1694822400, 'T2m', 'K', 291.23977113006237, 4.0, 0.0), (1694822400.0, 0.0, 6240, 2, 52.3156, 4.7903, 1694822400, 'T2m', 'K', 289.80632615020863, -2.69, 0.0), (1694822400.0, 0.0, 6248, 2, 52.6325, 5.1736, 1694822400, 'T2m', 'K', 291.01878207117517, 0.8, 0.0), (1694822400.0, 0.0, 6249, 2, 52.6428, 4.9789, 1694822400, 'T2m', 'K', 289.65065645723695, -2.4, 0.0), (1694822400.0, 0.0, 6254, 2, 52.27, 4.3, 1694822400, 'T2m', 'K', 291.9286047081635, 17.0, 0.0), (1694822400.0, 0.0, 6257, 2, 52.5053, 4.6031, 1694822400, 'T2m', 'K', 290.30222024796495, 8.5, 0.0), (1694822400.0, 0.0, 6258, 2, 52.6481, 5.4006, 1694822400, 'T2m', 'K', 292.1171931656377, 7.25, 0.0), (1694822400.0, 0.0, 6260, 2, 52.0989, 5.1797, 1694822400, 'T2m', 'K', 290.40183144286465, 3
# ...
